# %%
import pandas as pd
import pickle

# Load the final model
model = pickle.load(
    open("Lead_Scoring_Final_Model.pkl", "rb"))

# Create a new lead
new_lead = pd.DataFrame([{
    'Lead_ID': 11801,
    'Total_Visits': 15,
    'Time_Spent_Website': 650,
    'Page_Views': 10,
    'Email_Opens': 8,
    'Email_Clicks': 5,
    'Previous_Interactions': 12,
    'Lead_Quality_Score': 75,
    'Age': 35,
    'Annual_Income': 45000,
    'Sales_Calls': 5,
    'Days_Since_Last_Activity': 20,

    'Lead_Source_Facebook': 0,
    'Lead_Source_Google': 1,
    'Lead_Source_LinkedIn': 0,
    'Lead_Source_Referral': 0,
    'Lead_Source_Website': 0,

    'Industry_Finance': 0,
    'Industry_Healthcare': 1,
    'Industry_IT': 0,
    'Industry_Manufacturing': 0,
    'Industry_Retail': 0
}])

# Make prediction
prediction = model.predict(new_lead)

print("Estimated Lead Value:", prediction[0])
# Out:
# Estimated Lead Value: 107640.67618026012
